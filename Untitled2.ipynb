# %%
import glob
import os
path = '/data/dataset/torcs/tmp1'

file_list = glob.glob('{}/*jpg'.format(path))

file_list.sort( key = lambda i : i.replace('/data/dataset/torcs/tmp1/' ,'').replace('.jpg' ,'').replace('.' ,'').replace(':' ,''))
sample = file_list[::10][:16]

# %%
ls ./dataset/int_data2
# Out:
# 0.jpg   11.jpg  13.jpg  15.jpg  2.jpg  4.jpg  6.jpg  8.jpg
# 10.jpg  12.jpg  14.jpg  1.jpg   3.jpg  5.jpg  7.jpg  9.jpg

# %%
for i ,j in enumerate(sample):
    img = cv2.imread(j)
    img = cv2.resize(img , (160,80))
    cv2.imwrite('/home/sdc/waxz/research/int1/{}.jpg'.format(i) ,img)

# %%
cp -r /home/sdc/waxz/research/int1/ /home/sdc/waxz/research/dataset/int_data1

# %%
ls /home/sdc/waxz/research/dataset/int_data1/int1/
# Out:
# 0.jpg   11.jpg  13.jpg  15.jpg  2.jpg  4.jpg  6.jpg  8.jpg
# 10.jpg  12.jpg  14.jpg  1.jpg   3.jpg  5.jpg  7.jpg  9.jpg

# %%
file_list
# Out:
# ['/data/dataset/torcs/tmp1/20:05:53.004775.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.005572.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.021372.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.021665.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.021670.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.037961.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.038073.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.054652.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.054796.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.054967.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.071241.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.071301.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.071309.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.071437.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.071607.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.087892.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.103711.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.104648.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.104861.jpg',
# ...

# %%
file_list[0]
# Out:
# '/data/dataset/torcs/tmp1/20:05:54.425283.jpg'

# %%
file_list
# Out:
# ['/data/dataset/torcs/tmp1/20:05:53.004775.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.005572.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.021372.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.021665.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.021670.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.037961.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.038073.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.054652.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.054796.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.054967.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.071241.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.071301.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.071309.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.071437.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.071607.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.087892.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.103711.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.104648.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.104861.jpg',
# ...

# %%
ls /data/dataset/torcs/tmp1/
# Out:
# 20:05:50.021372.jpg  20:05:51.708484.jpg  20:05:53.388065.jpg
# 20:05:50.054652.jpg  20:05:51.725017.jpg  20:05:53.404762.jpg
# 20:05:50.071301.jpg  20:05:51.756727.jpg  20:05:53.438290.jpg
# 20:05:50.104648.jpg  20:05:51.791770.jpg  20:05:53.471387.jpg
# 20:05:50.138260.jpg  20:05:51.826442.jpg  20:05:53.504777.jpg
# 20:05:50.171728.jpg  20:05:51.844582.jpg  20:05:53.521655.jpg
# 20:05:50.203860.jpg  20:05:51.871692.jpg  20:05:53.554761.jpg
# 20:05:50.221216.jpg  20:05:51.905045.jpg  20:05:53.588126.jpg
# 20:05:50.254596.jpg  20:05:51.938325.jpg  20:05:53.621456.jpg
# 20:05:50.287902.jpg  20:05:51.954972.jpg  20:05:53.638122.jpg
# 20:05:50.304544.jpg  20:05:51.988428.jpg  20:05:53.671449.jpg
# 20:05:50.337955.jpg  20:05:52.021665.jpg  20:05:53.704802.jpg
# 20:05:50.371235.jpg  20:05:52.054967.jpg  20:05:53.738088.jpg
# 20:05:50.404656.jpg  20:05:52.071607.jpg  20:05:53.754793.jpg
# 20:05:50.421280.jpg  20:05:52.105020.jpg  20:05:53.788080.jpg
# ...

# %%
file_list.sort( key = lambda x : x.replace(
# Out:
# ['/data/dataset/torcs/tmp1/20:05:54.425283.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.738088.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.004775.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.287902.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.854698.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.388065.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.591828.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.556989.jpg',
#  '/data/dataset/torcs/tmp1/20:05:53.154683.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.304544.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.859047.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.254850.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.674835.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.054967.jpg',
#  '/data/dataset/torcs/tmp1/20:05:54.458589.jpg',
#  '/data/dataset/torcs/tmp1/20:05:50.171728.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.138055.jpg',
#  '/data/dataset/torcs/tmp1/20:05:51.287919.jpg',
#  '/data/dataset/torcs/tmp1/20:05:52.337950.jpg',
# ...

# %%
s = '/data/dataset/torcs/tmp1/20:05:52.138055.jpg'

# %%
s.replace('/data/dataset/torcs/tmp1/' ,'').replace('.jpg' ,'').replace('.' ,'').replace(':' ,'')
# Out:
# '200552138055'
